# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
# Out:
# 2.3.1

# %%
# Recreate the exact same model, including its weights and the optimizer
new_model = tf.keras.models.load_model('/home/amr/Documents/Makeathon/LAAD/pretrained models/A0NVTRV_model.h5')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 # Recreate the exact same model, including its weights and the optimizer
# ----> 2 new_model = tf.keras.models.load_model('/home/amr/Documents/Makeathon/LAAD/pretrained models/A0NVTRV_model.h5')
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py:182, in load_model(filepath, custom_objects, compile, options)
#     179 with generic_utils.CustomObjectScope(custom_objects or {}):
#     180   if (h5py is not None and (
#     181       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 182     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     184   filepath = path_to_string(filepath)
#     185   if isinstance(filepath, six.string_types):
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/saving/hdf5_format.py:177, in load_model_from_hdf5(filepath, custom_objects, compile)
#     175   raise ValueError('No model found in config file.')
#     176 model_config = json.loads(model_config.decode('utf-8'))
# --> 177 model = model_config_lib.model_from_config(model_config,
#     178                                            custom_objects=custom_objects)
#     180 # set weights
#     181 load_weights_from_hdf5_group(f['model_weights'], model.layers)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/saving/model_config.py:55, in model_from_config(config, custom_objects)
#      51   raise TypeError('`model_from_config` expects a dictionary, not a list. '
#      52                   'Maybe you meant to use '
#      53                   '`Sequential.from_config(config)`?')
#      54 from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 55 return deserialize(config, custom_objects=custom_objects)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/serialization.py:171, in deserialize(config, custom_objects)
#     160 """Instantiates a layer from a config dictionary.
#     161
#     162 Arguments:
#    (...)
#     168     Layer instance (may be Model, Sequential, Network, Layer...)
#     169 """
#     170 populate_deserializable_objects()
# --> 171 return generic_utils.deserialize_keras_object(
#     172     config,
#     173     module_objects=LOCAL.ALL_OBJECTS,
#     174     custom_objects=custom_objects,
#     175     printable_module_name='layer')
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:354, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     351 custom_objects = custom_objects or {}
#     353 if 'custom_objects' in arg_spec.args:
# --> 354   return cls.from_config(
#     355       cls_config,
#     356       custom_objects=dict(
#     357           list(_GLOBAL_CUSTOM_OBJECTS.items()) +
#     358           list(custom_objects.items())))
#     359 with CustomObjectScope(custom_objects):
#     360   return cls.from_config(cls_config)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:488, in Sequential.from_config(cls, config, custom_objects)
#     485 for layer_config in layer_configs:
#     486   layer = layer_module.deserialize(layer_config,
#     487                                    custom_objects=custom_objects)
# --> 488   model.add(layer)
#     489 if (not model.inputs and build_input_shape and
#     490     isinstance(build_input_shape, (tuple, list))):
#     491   model.build(build_input_shape)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py:457, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     455 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456 try:
# --> 457   result = method(self, *args, **kwargs)
#     458 finally:
#     459   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:221, in Sequential.add(self, layer)
#     216     self._has_explicit_input_shape = True
#     218 elif self.outputs:
#     219   # If the model is being built continuously on top of an input layer:
#     220   # refresh its output.
# --> 221   output_tensor = layer(self.outputs[0])
#     222   if len(nest.flatten(output_tensor)) != 1:
#     223     raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent.py:659, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     653 inputs, initial_state, constants = _standardize_args(inputs,
#     654                                                      initial_state,
#     655                                                      constants,
#     656                                                      self._num_constants)
#     658 if initial_state is None and constants is None:
# --> 659   return super(RNN, self).__call__(inputs, **kwargs)
#     661 # If any of `initial_state` or `constants` are specified and are Keras
#     662 # tensors, then add them to the inputs and temporarily modify the
#     663 # input_spec to include them.
#     665 additional_inputs = []
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:925, in Layer.__call__(self, *args, **kwargs)
#     919 # Functional Model construction mode is invoked when `Layer`s are called on
#     920 # symbolic `KerasTensor`s, i.e.:
#     921 # >> inputs = tf.keras.Input(10)
#     922 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#     923 # >> model = tf.keras.Model(inputs, outputs)
#     924 if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 925   return self._functional_construction_call(inputs, args, kwargs,
#     926                                             input_list)
#     928 # Maintains info about the `Layer.call` stack.
#     929 call_context = base_layer_utils.call_context()
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:1117, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    1115 try:
#    1116   with ops.enable_auto_cast_variables(self._compute_dtype_object):
# -> 1117     outputs = call_fn(cast_inputs, *args, **kwargs)
#    1119 except errors.OperatorNotAllowedInGraphError as e:
#    1120   raise TypeError('You are attempting to use Python control '
#    1121                   'flow in a layer that was not declared to be '
#    1122                   'dynamic. Pass `dynamic=True` to the class '
#    1123                   'constructor.\nEncountered error:\n"""\n' + str(e) +
#    1124                   '\n"""')
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent_v2.py:1108, in LSTM.call(self, inputs, mask, training, initial_state)
#    1105 self._validate_args_if_ragged(is_ragged_input, mask)
#    1107 # LSTM does not support constants. Ignore it during process.
# -> 1108 inputs, initial_state, _ = self._process_inputs(inputs, initial_state, None)
#    1110 if isinstance(mask, list):
#    1111   mask = mask[0]
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent.py:858, in RNN._process_inputs(self, inputs, initial_state, constants)
#     856     initial_state = self.states
#     857 elif initial_state is None:
# --> 858   initial_state = self.get_initial_state(inputs)
#     860 if len(initial_state) != len(self.states):
#     861   raise ValueError('Layer has ' + str(len(self.states)) +
#     862                    ' states but was passed ' + str(len(initial_state)) +
#     863                    ' initial states.')
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent.py:641, in RNN.get_initial_state(self, inputs)
#     639 dtype = inputs.dtype
#     640 if get_initial_state_fn:
# --> 641   init_state = get_initial_state_fn(
#     642       inputs=None, batch_size=batch_size, dtype=dtype)
#     643 else:
#     644   init_state = _generate_zero_filled_state(batch_size, self.cell.state_size,
#     645                                            dtype)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent.py:2519, in LSTMCell.get_initial_state(self, inputs, batch_size, dtype)
#    2518 def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
# -> 2519   return list(_generate_zero_filled_state_for_cell(
#    2520       self, inputs, batch_size, dtype))
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent.py:2964, in _generate_zero_filled_state_for_cell(cell, inputs, batch_size, dtype)
#    2962   batch_size = array_ops.shape(inputs)[0]
#    2963   dtype = inputs.dtype
# -> 2964 return _generate_zero_filled_state(batch_size, cell.state_size, dtype)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent.py:2980, in _generate_zero_filled_state(batch_size_tensor, state_size, dtype)
#    2977   return array_ops.zeros(init_state_size, dtype=dtype)
#    2979 if nest.is_sequence(state_size):
# -> 2980   return nest.map_structure(create_zeros, state_size)
#    2981 else:
#    2982   return create_zeros(state_size)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py:635, in map_structure(func, *structure, **kwargs)
#     631 flat_structure = [flatten(s, expand_composites) for s in structure]
#     632 entries = zip(*flat_structure)
#     634 return pack_sequence_as(
# --> 635     structure[0], [func(*x) for x in entries],
#     636     expand_composites=expand_composites)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py:635, in <listcomp>(.0)
#     631 flat_structure = [flatten(s, expand_composites) for s in structure]
#     632 entries = zip(*flat_structure)
#     634 return pack_sequence_as(
# --> 635     structure[0], [func(*x) for x in entries],
#     636     expand_composites=expand_composites)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/recurrent.py:2977, in _generate_zero_filled_state.<locals>.create_zeros(unnested_state_size)
#    2975 flat_dims = tensor_shape.as_shape(unnested_state_size).as_list()
#    2976 init_state_size = [batch_size_tensor] + flat_dims
# -> 2977 return array_ops.zeros(init_state_size, dtype=dtype)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:2747, in _tag_zeros_tensor.<locals>.wrapped(*args, **kwargs)
#    2746 def wrapped(*args, **kwargs):
# -> 2747   tensor = fun(*args, **kwargs)
#    2748   tensor._is_zeros_tensor = True
#    2749   return tensor
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:2794, in zeros(shape, dtype, name)
#    2790 try:
#    2791   if not context.executing_eagerly():
#    2792     # Create a constant if it won't be very big. Otherwise create a fill
#    2793     # op to prevent serialized GraphDefs from becoming too large.
# -> 2794     output = _constant_if_small(zero, shape, dtype, name)
#    2795     if output is not None:
#    2796       return output
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:2732, in _constant_if_small(value, shape, dtype, name)
#    2730 def _constant_if_small(value, shape, dtype, name):
#    2731   try:
# -> 2732     if np.prod(shape) < 1000:
#    2733       return constant(value, shape=shape, dtype=dtype, name=name)
#    2734   except TypeError:
#    2735     # Happens when shape is a Tensor, list with Tensor elements, etc.
#
# File <__array_function__ internals>:180, in prod(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3045, in prod(a, axis, dtype, out, keepdims, initial, where)
#    2927 @array_function_dispatch(_prod_dispatcher)
#    2928 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2929          initial=np._NoValue, where=np._NoValue):
#    2930     """
#    2931     Return the product of array elements over a given axis.
#    2932
#    (...)
#    3043     10
#    3044     """
# -> 3045     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3046                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:845, in Tensor.__array__(self)
#     844 def __array__(self):
# --> 845   raise NotImplementedError(
#     846       "Cannot convert a symbolic Tensor ({}) to a numpy array."
#     847       " This error may indicate that you're trying to pass a Tensor to"
#     848       " a NumPy call, which is not supported".format(self.name))
#
# NotImplementedError: Cannot convert a symbolic Tensor (lstm/strided_slice_1:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported
